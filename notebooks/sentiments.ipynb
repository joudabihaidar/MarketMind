# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
import pandas as pd

# %%
df=pd.read_csv(r'..\data\News.csv')
df.head(3)
# Out:
#                         Date  \
# 0  2024-05-07 15:18:14+00:00
# 1  2024-05-07 15:03:07+00:00
# 2  2024-05-07 14:48:29+00:00
#
#                                        article_title  \
# 0  Signs of the Top? Warren Buffett Selling His B...
# 1  Apple interrogation of NYC worker about union ...
# 2  Apple unveils new AI-focused chip in upgraded ...
#
#                                              article    source_name  \
# 0  Warren Buffett has built a massive position in...  Yahoo Finance
# 1  By Daniel Wiessner(Reuters) - The manager of a...  Yahoo Finance
# 2  By Stephen Nellis(Reuters) -Apple on Tuesday i...  Yahoo Finance
#
#                                          source_link ticker_symbol  Positive  \
# 0  https://finance.yahoo.com/news/signs-top-warre...          AAPL       NaN
# 1  https://finance.yahoo.com/news/apple-interroga...          AAPL       NaN
# 2  https://finance.yahoo.com/news/apple-expected-...          AAPL       NaN
#
#    Negative  Neutral  Compound Sentiment
# 0       NaN      NaN       NaN       NaN
# 1       NaN      NaN       NaN       NaN
# 2       NaN      NaN       NaN       NaN

# %%
sentiments = SentimentIntensityAnalyzer()


positive_scores = []
negative_scores = []
neutral_scores = []
compound_scores = []


for article in df["article"]:
    scores = sentiments.polarity_scores(article)
    positive_scores.append(scores["pos"])
    negative_scores.append(scores["neg"])
    neutral_scores.append(scores["neu"])
    compound_scores.append(scores["compound"])


df["Positive"] = positive_scores
df["Negative"] = negative_scores
df["Neutral"] = neutral_scores
df["Compound"] = compound_scores

# %%
score = df["Compound"].values
sentiment = []
for i in score:
    if i >= 0.5 :
        sentiment.append('Positive')
    elif i <= -0.5 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
df["Sentiment"] = sentiment

# %%
df
# Out:
#                            Date  \
# 0     2024-05-07 15:18:14+00:00
# 1     2024-05-07 15:03:07+00:00
# 2     2024-05-07 14:48:29+00:00
# 3     2024-05-07 14:37:00+00:00
# 4     2024-05-07 14:37:00+00:00
# ...                         ...
# 1036  2024-03-05 16:59:20+00:00
# 1037  2024-03-05 16:55:49+00:00
# 1038  2024-03-05 16:46:00+00:00
# 1039  2024-03-05 16:43:00+00:00
# 1040  2024-03-05 16:27:00+00:00
#
#                                           article_title  \
# 0     Signs of the Top? Warren Buffett Selling His B...
# 1     Apple interrogation of NYC worker about union ...
# 2     Apple unveils new AI-focused chip in upgraded ...
# 3     Apple unveils stunning new iPad Pro with the w...
# 4     Final Cut Pro transforms video creation with L...
# ...                                                 ...
# 1036  Apple Stock Gloom Deepens as Pressure to Show ...
# 1037  What the shakeup in Magnificent 7 stocks means...
# 1038  Alphabet (GOOGL) Enhances Google Maps With New...
# 1039  Why Apple Stock Keeps Dropping, and What Could...
# 1040  Apple iPhone Sales Are Slipping in China. The ...
#
#                                                 article    source_name  \
# 0     Warren Buffett has built a massive position in...  Yahoo Finance
# 1     By Daniel Wiessner(Reuters) - The manager of a...  Yahoo Finance
# 2     By Stephen Nellis(Reuters) -Apple on Tuesday i...  Yahoo Finance
# 3     Featuring a new thin and light design, breakth...  Yahoo Finance
# 4     Final Cut Pro for iPad 2 delivers support for ...  Yahoo Finance
# ...                                                 ...            ...
# 1036  (Bloomberg) -- Apple Inc.’s move to shutter it...  Yahoo Finance
# 1037  Stock market indices have been propped up on t...  Yahoo Finance
# 1038  Alphabet’s GOOGL Google is gaining strong mome...  Yahoo Finance
# 1039  Apple stock is in the red this year, so Wall S...  Yahoo Finance
# 1040  Weakness in China is the latest sign that Appl...  Yahoo Finance
#
#                                             source_link ticker_symbol  \
# 0     https://finance.yahoo.com/news/signs-top-warre...          AAPL
# 1     https://finance.yahoo.com/news/apple-interroga...          AAPL
# 2     https://finance.yahoo.com/news/apple-expected-...          AAPL
# 3     https://finance.yahoo.com/news/apple-unveils-s...          AAPL
# 4     https://finance.yahoo.com/news/final-cut-pro-t...          AAPL
# ...                                                 ...           ...
# 1036  https://finance.yahoo.com/quote/AAPL/news/appl...          AAPL
# 1037  https://finance.yahoo.com/quote/AAPL/video/sha...          AAPL
# 1038  https://finance.yahoo.com/quote/AAPL/news/alph...          AAPL
# 1039  https://finance.yahoo.com/quote/AAPL/m/c76aec8...          AAPL
# 1040  https://finance.yahoo.com/quote/AAPL/m/d6d45fc...          AAPL
#
#       Positive  Negative  Neutral  Compound Sentiment
# 0        0.058     0.070    0.872   -0.5502  Negative
# 1        0.018     0.097    0.885   -0.9686  Negative
# 2        0.069     0.035    0.896    0.9819  Positive
# 3        0.114     0.015    0.871    0.9999  Positive
# 4        0.120     0.056    0.824    0.9986  Positive
# ...        ...       ...      ...       ...       ...
# 1036     0.055     0.051    0.894   -0.0880   Neutral
# 1037     0.118     0.028    0.854    0.9988  Positive
# 1038     0.171     0.000    0.829    0.9982  Positive
# 1039     0.000     0.038    0.962   -0.4767   Neutral
# 1040     0.000     0.212    0.788   -0.6249  Negative
#
# [1041 rows x 11 columns]

# %%
df.to_csv(r'..\data\News.csv',index=False)
