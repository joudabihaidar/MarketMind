# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
import pandas as pd

# %%
df=pd.read_csv(r'..\data\NewsWithStockPrice.csv')
df.head(3)
# Out:
#                   Date                                      article_title  \
# 0  2024-04-29 19:59:00               Apple Earnings: Time to Take a Bite?
# 1  2024-04-29 19:46:00            15 Fastest Growing Cities in California
# 2  2024-04-29 19:40:00  US STOCKS-Wall Street stocks gain as investors...
#
#                                              article    source_name  \
# 0  It’s another busy slate of earnings this week,...  Yahoo Finance
# 1  In this article, we will take a look at the 15...  Yahoo Finance
# 2  *Tesla gains after clearing self-driving hurdl...  Yahoo Finance
#
#                                          source_link ticker_symbol  \
# 0  https://finance.yahoo.com/news/apple-earnings-...          AAPL
# 1  https://finance.yahoo.com/news/15-fastest-grow...          AAPL
# 2  https://finance.yahoo.com/news/us-stocks-wall-...          AAPL
#
#    stock_price  stock_price_after_30_mins  change_percentage  label
# 0   173.824997                 173.490005          -0.192718     -1
# 1   173.743301                 173.845001           0.058535      0
# 2   173.710007                 173.839996           0.074831      0

# %%
sentiments = SentimentIntensityAnalyzer()


positive_scores = []
negative_scores = []
neutral_scores = []
compound_scores = []


for article in df["article"]:
    scores = sentiments.polarity_scores(article)
    positive_scores.append(scores["pos"])
    negative_scores.append(scores["neg"])
    neutral_scores.append(scores["neu"])
    compound_scores.append(scores["compound"])


df["Positive"] = positive_scores
df["Negative"] = negative_scores
df["Neutral"] = neutral_scores
df["Compound"] = compound_scores

# %%
score = df["Compound"].values
sentiment = []
for i in score:
    if i >= 0.5 :
        sentiment.append('Positive')
    elif i <= -0.5 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
df["Sentiment"] = sentiment

# %%
df
# Out:
#                     Date                                      article_title  \
# 0    2024-04-29 19:59:00               Apple Earnings: Time to Take a Bite?
# 1    2024-04-29 19:46:00            15 Fastest Growing Cities in California
# 2    2024-04-29 19:40:00  US STOCKS-Wall Street stocks gain as investors...
# 3    2024-04-29 18:19:00   Tesla, Apple Help US Equity Indexes Extend Gains
# 4    2024-04-29 17:58:00  What Would Happen If Warren Buffett Bailed On ...
# ..                   ...                                                ...
# 359  2024-03-05 17:40:00                             Goodbye, Project Titan
# 360  2024-03-05 17:29:00  Apple Stock Gloom Deepens as Pressure to Show ...
# 361  2024-03-05 17:25:00  What the shakeup in Magnificent 7 stocks means...
# 362  2024-03-05 17:16:00  Alphabet (GOOGL) Enhances Google Maps With New...
# 363  2024-03-05 17:13:00  Why Apple Stock Keeps Dropping, and What Could...
#
#                                                article    source_name  \
# 0    It’s another busy slate of earnings this week,...  Yahoo Finance
# 1    In this article, we will take a look at the 15...  Yahoo Finance
# 2    *Tesla gains after clearing self-driving hurdl...  Yahoo Finance
# 3     Tesla, Apple Help US Equity Indexes Extend Gains  Yahoo Finance
# 4    Benzinga and Yahoo Finance LLC may earn commis...  Yahoo Finance
# ..                                                 ...            ...
# 359  In this podcast, Motley Fool analyst Asit Shar...  Yahoo Finance
# 360  (Bloomberg) -- Apple Inc.’s move to shutter it...  Yahoo Finance
# 361  Stock market indices have been propped up on t...  Yahoo Finance
# 362  Alphabet’s GOOGL Google is gaining strong mome...  Yahoo Finance
# 363  Apple stock is in the red this year, so Wall S...  Yahoo Finance
#
#                                            source_link ticker_symbol  \
# 0    https://finance.yahoo.com/news/apple-earnings-...          AAPL
# 1    https://finance.yahoo.com/news/15-fastest-grow...          AAPL
# 2    https://finance.yahoo.com/news/us-stocks-wall-...          AAPL
# 3    https://finance.yahoo.com/news/tesla-apple-hel...          AAPL
# 4    https://finance.yahoo.com/news/happen-warren-b...          AAPL
# ..                                                 ...           ...
# 359  https://finance.yahoo.com/quote/AAPL/news/good...           NaN
# 360  https://finance.yahoo.com/quote/AAPL/news/appl...           NaN
# 361  https://finance.yahoo.com/quote/AAPL/video/sha...           NaN
# 362  https://finance.yahoo.com/quote/AAPL/news/alph...           NaN
# 363  https://finance.yahoo.com/quote/AAPL/m/c76aec8...           NaN
#
#      stock_price  stock_price_after_30_mins  change_percentage  label  \
# 0     173.824997                 173.490005          -0.192718     -1
# 1     173.743301                 173.845001           0.058535      0
# 2     173.710007                 173.839996           0.074831      0
# 3     174.720001                 174.302094          -0.239187     -1
# 4     174.809998                 174.755005          -0.031459      0
# ..           ...                        ...                ...    ...
# 359   170.503799                 170.317596          -0.109208     -1
# 360   170.259201                 170.785004           0.308825      1
# 361   170.160004                 170.804993           0.379049      1
# 362   169.865005                 170.692505           0.487151      1
# 363   169.970001                 170.528793           0.328759      1
#
#      Positive  Negative  Neutral  Compound Sentiment
# 0       0.092     0.049    0.859    0.9766  Positive
# 1       0.081     0.011    0.907    0.9981  Positive
# 2       0.096     0.015    0.888    0.9907  Positive
# 3       0.576     0.000    0.424    0.7003  Positive
# 4       0.107     0.029    0.864    0.9923  Positive
# ..        ...       ...      ...       ...       ...
# 359     0.122     0.042    0.836    0.9999  Positive
# 360     0.055     0.051    0.894   -0.0880   Neutral
# 361     0.118     0.028    0.854    0.9988  Positive
# 362     0.171     0.000    0.829    0.9982  Positive
# 363     0.000     0.038    0.962   -0.4767   Neutral
#
# [364 rows x 15 columns]

# %%
df.to_csv(r'..\data\NewsSentiments.csv',index=False)
