# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
import pandas as pd

# %%
df=pd.read_csv(r'..\data\News.csv')
df.head(3)
# Out:
#                         Date  \
# 0  2024-05-02 16:20:34+00:00
# 1  2024-05-02 16:11:44+00:00
# 2  2024-05-02 15:14:49+00:00
#
#                                        article_title  \
# 0             25 Most Profitable Companies in the US
# 1  Top 25 Stocks in the S&P 500 by Index Weight R...
# 2  Why analysts are expecting a rough earnings re...
#
#                                              article    source_name  \
# 0  In this piece, we will take a look at the 25 m...  Yahoo Finance
# 1  In this piece, we will take a look at the top ...  Yahoo Finance
# 2  Even though Apple has silenced critics and bea...  Yahoo Finance
#
#                                          source_link ticker_symbol  Positive  \
# 0  https://finance.yahoo.com/news/25-most-profita...          AAPL       NaN
# 1  https://finance.yahoo.com/news/top-25-stocks-p...          AAPL       NaN
# 2  https://finance.yahoo.com/news/apple-set-repor...          AAPL       NaN
#
#    Negative  Neutral  Compound Sentiment
# 0       NaN      NaN       NaN       NaN
# 1       NaN      NaN       NaN       NaN
# 2       NaN      NaN       NaN       NaN

# %%
sentiments = SentimentIntensityAnalyzer()


positive_scores = []
negative_scores = []
neutral_scores = []
compound_scores = []


for article in df["article"]:
    scores = sentiments.polarity_scores(article)
    positive_scores.append(scores["pos"])
    negative_scores.append(scores["neg"])
    neutral_scores.append(scores["neu"])
    compound_scores.append(scores["compound"])


df["Positive"] = positive_scores
df["Negative"] = negative_scores
df["Neutral"] = neutral_scores
df["Compound"] = compound_scores

# %%
score = df["Compound"].values
sentiment = []
for i in score:
    if i >= 0.5 :
        sentiment.append('Positive')
    elif i <= -0.5 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
df["Sentiment"] = sentiment

# %%
df
# Out:
#                            Date  \
# 0     2024-05-02 16:20:34+00:00
# 1     2024-05-02 16:11:44+00:00
# 2     2024-05-02 15:14:49+00:00
# 3     2024-05-02 15:04:00+00:00
# 4     2024-05-02 15:00:14+00:00
# ...                         ...
# 1009  2024-03-05 16:59:20+00:00
# 1010  2024-03-05 16:55:49+00:00
# 1011  2024-03-05 16:46:00+00:00
# 1012  2024-03-05 16:43:00+00:00
# 1013  2024-03-05 16:27:00+00:00
#
#                                           article_title  \
# 0                25 Most Profitable Companies in the US
# 1     Top 25 Stocks in the S&P 500 by Index Weight R...
# 2     Why analysts are expecting a rough earnings re...
# 3     Apple to extend new core technology fee to iPa...
# 4     Apple adds more carve-outs to its EU core tech...
# ...                                                 ...
# 1009  Apple Stock Gloom Deepens as Pressure to Show ...
# 1010  What the shakeup in Magnificent 7 stocks means...
# 1011  Alphabet (GOOGL) Enhances Google Maps With New...
# 1012  Why Apple Stock Keeps Dropping, and What Could...
# 1013  Apple iPhone Sales Are Slipping in China. The ...
#
#                                                 article    source_name  \
# 0     In this piece, we will take a look at the 25 m...  Yahoo Finance
# 1     In this piece, we will take a look at the top ...  Yahoo Finance
# 2     Even though Apple has silenced critics and bea...  Yahoo Finance
# 3     By Foo Yun CheeBRUSSELS (Reuters) - Apple will...  Yahoo Finance
# 4     Apple is tweaking how it applies a new fee tha...  Yahoo Finance
# ...                                                 ...            ...
# 1009  (Bloomberg) -- Apple Inc.’s move to shutter it...  Yahoo Finance
# 1010  Stock market indices have been propped up on t...  Yahoo Finance
# 1011  Alphabet’s GOOGL Google is gaining strong mome...  Yahoo Finance
# 1012  Apple stock is in the red this year, so Wall S...  Yahoo Finance
# 1013  Weakness in China is the latest sign that Appl...  Yahoo Finance
#
#                                             source_link ticker_symbol  \
# 0     https://finance.yahoo.com/news/25-most-profita...          AAPL
# 1     https://finance.yahoo.com/news/top-25-stocks-p...          AAPL
# 2     https://finance.yahoo.com/news/apple-set-repor...          AAPL
# 3     https://finance.yahoo.com/news/apple-extend-co...          AAPL
# 4     https://finance.yahoo.com/news/apple-adds-more...          AAPL
# ...                                                 ...           ...
# 1009  https://finance.yahoo.com/quote/AAPL/news/appl...          AAPL
# 1010  https://finance.yahoo.com/quote/AAPL/video/sha...          AAPL
# 1011  https://finance.yahoo.com/quote/AAPL/news/alph...          AAPL
# 1012  https://finance.yahoo.com/quote/AAPL/m/c76aec8...          AAPL
# 1013  https://finance.yahoo.com/quote/AAPL/m/d6d45fc...          AAPL
#
#       Positive  Negative  Neutral  Compound Sentiment
# 0        0.107     0.025    0.869    0.9992  Positive
# 1        0.114     0.047    0.839    0.9987  Positive
# 2        0.089     0.040    0.871    0.9809  Positive
# 3        0.037     0.026    0.937    0.5562  Positive
# 4        0.071     0.018    0.911    0.9916  Positive
# ...        ...       ...      ...       ...       ...
# 1009     0.055     0.051    0.894   -0.0880   Neutral
# 1010     0.118     0.028    0.854    0.9988  Positive
# 1011     0.171     0.000    0.829    0.9982  Positive
# 1012     0.000     0.038    0.962   -0.4767   Neutral
# 1013     0.000     0.212    0.788   -0.6249  Negative
#
# [1014 rows x 11 columns]

# %%
df.to_csv(r'..\data\News.csv',index=False)
