# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
import pandas as pd

# %%
df=pd.read_csv(r'..\data\NewsWithStockPrice.csv')
df.head(3)
# Out:
#                   Date                                      article_title  \
# 0  2024-04-30 18:37:00  Apple's Secret AI Lab in Zurich Poised to Enha...
# 1  2024-04-30 18:23:00  Apple Likely to Meet Q2 Guidance, But Q3 Outlo...
# 2  2024-04-30 17:18:00  Q1 Earnings Season Scorecard and Fresh Researc...
#
#                                              article    source_name  \
# 0  Apple Inc (NASDAQ:AAPL) has aggressively recru...  Yahoo Finance
# 1  Apple Likely to Meet Q2 Guidance, But Q3 Outlo...  Yahoo Finance
# 2  Tuesday, April 30, 2024Today's Research Daily ...  Yahoo Finance
#
#                                          source_link ticker_symbol  \
# 0  https://finance.yahoo.com/news/apples-secret-a...          AAPL
# 1  https://finance.yahoo.com/news/apple-likely-me...          AAPL
# 2  https://finance.yahoo.com/news/q1-earnings-sea...          AAPL
#
#    stock_price  stock_price_after_30_mins  change_percentage  label
# 0   173.657700                 173.251602          -0.233849     -1
# 1   173.654999                 173.339996          -0.181396     -1
# 2   173.274994                 173.296494           0.012408      0

# %%
sentiments = SentimentIntensityAnalyzer()


positive_scores = []
negative_scores = []
neutral_scores = []
compound_scores = []


for article in df["article"]:
    scores = sentiments.polarity_scores(article)
    positive_scores.append(scores["pos"])
    negative_scores.append(scores["neg"])
    neutral_scores.append(scores["neu"])
    compound_scores.append(scores["compound"])


df["Positive"] = positive_scores
df["Negative"] = negative_scores
df["Neutral"] = neutral_scores
df["Compound"] = compound_scores

# %%
score = df["Compound"].values
sentiment = []
for i in score:
    if i >= 0.5 :
        sentiment.append('Positive')
    elif i <= -0.5 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
df["Sentiment"] = sentiment

# %%
df
# Out:
#                     Date                                      article_title  \
# 0    2024-04-30 18:37:00  Apple's Secret AI Lab in Zurich Poised to Enha...
# 1    2024-04-30 18:23:00  Apple Likely to Meet Q2 Guidance, But Q3 Outlo...
# 2    2024-04-30 17:18:00  Q1 Earnings Season Scorecard and Fresh Researc...
# 3    2024-04-29 17:19:00  Apple's iPadOS will have to comply with EU's D...
# 4    2024-04-29 19:59:00               Apple Earnings: Time to Take a Bite?
# ..                   ...                                                ...
# 363  2024-03-05 17:40:00                             Goodbye, Project Titan
# 364  2024-03-05 17:29:00  Apple Stock Gloom Deepens as Pressure to Show ...
# 365  2024-03-05 17:25:00  What the shakeup in Magnificent 7 stocks means...
# 366  2024-03-05 17:16:00  Alphabet (GOOGL) Enhances Google Maps With New...
# 367  2024-03-05 17:13:00  Why Apple Stock Keeps Dropping, and What Could...
#
#                                                article    source_name  \
# 0    Apple Inc (NASDAQ:AAPL) has aggressively recru...  Yahoo Finance
# 1    Apple Likely to Meet Q2 Guidance, But Q3 Outlo...  Yahoo Finance
# 2    Tuesday, April 30, 2024Today's Research Daily ...  Yahoo Finance
# 3    The European Union will apply its flagship mar...  Yahoo Finance
# 4    It’s another busy slate of earnings this week,...  Yahoo Finance
# ..                                                 ...            ...
# 363  In this podcast, Motley Fool analyst Asit Shar...  Yahoo Finance
# 364  (Bloomberg) -- Apple Inc.’s move to shutter it...  Yahoo Finance
# 365  Stock market indices have been propped up on t...  Yahoo Finance
# 366  Alphabet’s GOOGL Google is gaining strong mome...  Yahoo Finance
# 367  Apple stock is in the red this year, so Wall S...  Yahoo Finance
#
#                                            source_link ticker_symbol  \
# 0    https://finance.yahoo.com/news/apples-secret-a...          AAPL
# 1    https://finance.yahoo.com/news/apple-likely-me...          AAPL
# 2    https://finance.yahoo.com/news/q1-earnings-sea...          AAPL
# 3    https://finance.yahoo.com/news/apples-ipados-c...          AAPL
# 4    https://finance.yahoo.com/news/apple-earnings-...          AAPL
# ..                                                 ...           ...
# 363  https://finance.yahoo.com/quote/AAPL/news/good...           NaN
# 364  https://finance.yahoo.com/quote/AAPL/news/appl...           NaN
# 365  https://finance.yahoo.com/quote/AAPL/video/sha...           NaN
# 366  https://finance.yahoo.com/quote/AAPL/news/alph...           NaN
# 367  https://finance.yahoo.com/quote/AAPL/m/c76aec8...           NaN
#
#      stock_price  stock_price_after_30_mins  change_percentage  label  \
# 0     173.657700                 173.251602          -0.233849     -1
# 1     173.654999                 173.339996          -0.181396     -1
# 2     173.274994                 173.296494           0.012408      0
# 3     174.359894                 174.442505           0.047380      0
# 4     173.824997                 173.490005          -0.192718     -1
# ..           ...                        ...                ...    ...
# 363   170.503799                 170.317596          -0.109208     -1
# 364   170.259201                 170.785004           0.308825      1
# 365   170.160004                 170.804993           0.379049      1
# 366   169.865005                 170.692505           0.487151      1
# 367   169.970001                 170.528793           0.328759      1
#
#      Positive  Negative  Neutral  Compound Sentiment
# 0       0.105     0.027    0.868    0.9863  Positive
# 1       0.000     0.128    0.872   -0.2263   Neutral
# 2       0.158     0.028    0.813    0.9995  Positive
# 3       0.063     0.024    0.913    0.9568  Positive
# 4       0.092     0.049    0.859    0.9766  Positive
# ..        ...       ...      ...       ...       ...
# 363     0.122     0.042    0.836    0.9999  Positive
# 364     0.055     0.051    0.894   -0.0880   Neutral
# 365     0.118     0.028    0.854    0.9988  Positive
# 366     0.171     0.000    0.829    0.9982  Positive
# 367     0.000     0.038    0.962   -0.4767   Neutral
#
# [368 rows x 15 columns]

# %%
df.to_csv(r'..\data\NewsSentiments.csv',index=False)
