# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta
import pytz

# %%
def removeSeconds(df):
    modified_dates=[]
    for date in df['Date']:
        format = '%Y-%m-%d %H:%M:%S%z'
        date = datetime.strptime(date, format)
        modified_date = date.replace(second=0)
        modified_dates.append(modified_date)
    df['Date']=modified_dates
    return df

# %%
def convertTimezone(timezone, df,name):
    """
    Converting timestamps in to a specified timezone. 

    Arguments:
        timezone (str): Target timezone to convert timestamps to.
        df : DataFrame containing a column of timestamp strings.
        name: name of the timestamp column

    Returns a dataFrame with timestamps converted to the specified timezone.
    """

    target_tz = pytz.timezone(timezone)

    if df.index is not None:
        # Convert the index to a timezone-aware index
        df.index = pd.to_datetime(df.index, utc=True).tz_convert(timezone)

    else:
        # Convert timestamp column to datetime objects
        df[name] = pd.to_datetime(df[name],utc=True)
        df[name] = df[name].dt.tz_convert(target_tz)
    return df

# %%
def getStockPrices(start_date,end_date):

    start_date = datetime.strptime(start_date, "%Y-%m-%d")
    end_date = datetime.strptime(end_date, "%Y-%m-%d")
    interval = "1m"                     

    current_date = start_date
    # Initialize an empty list to store data
    data_list = []  

    while current_date < end_date:
        remaining_days = (end_date - current_date).days
        
        if remaining_days < 7:
            # If remaining days are less than 7, get data till end_date
            data = yf.download("AAPL", start=current_date, end=end_date, interval=interval)
            data = convertTimezone('UTC', data, 'Datetime')
            # Append data to the list
            data_list.append(data)
            current_date = end_date
        else:
            # If remaining days are 7 or more, get data for the next 7 days
            next_date = current_date + timedelta(days=7)
            data = yf.download("AAPL", start=current_date, end=next_date, interval=interval)
            data = convertTimezone('UTC', data, 'Datetime')
            # Append data to the list
            data_list.append(data)
            current_date = next_date

    # Concatenate the list of dataframes into a single dataframe
    final_data = pd.concat(data_list)
    final_data.reset_index(inplace=True)
    return final_data

# %%
def addStockPrices(stockPrices,df):

    # df=removeSeconds(df)

    stockPrices['Datetime'] = pd.to_datetime(stockPrices['Datetime'])
    stockPrices['Datetime'] = stockPrices['Datetime'].dt.strftime('%Y-%m-%d %H:%M:%S')

    df['Date'] = pd.to_datetime(df['Date'])
    df['Date'] = df['Date'].dt.strftime('%Y-%m-%d %H:%M:%S')

    # store stock prices
    stock_prices = []

    # Iterate through each row in the News dataset
    for index, row in df.iterrows():
        publication_date = row['Date']
        # Check if the publication date exists in the stockPrice dataset
        if publication_date in stockPrices['Datetime'].values:
            # Retrieve the corresponding stock price
            stock_price = stockPrices.loc[stockPrices['Datetime'] == publication_date, 'Adj Close'].values[0]
            stock_prices.append(stock_price)
        else:
            stock_prices.append(None)  # If publication date not found, append None

    # Add the list of stock prices to the News dataset as a new column
    df['stock_price'] = stock_prices
    return df

# %%
def addStockPricesAfter(stockPrices,df,time):

    # df=removeSeconds(df)

    stockPrices['Datetime'] = pd.to_datetime(stockPrices['Datetime'])
    stockPrices['Datetime'] = stockPrices['Datetime'].dt.strftime('%Y-%m-%d %H:%M:%S')

    df['Date'] = pd.to_datetime(df['Date'])
    df['Date']+=timedelta(minutes=time)
    df['Date'] = df['Date'].dt.strftime('%Y-%m-%d %H:%M:%S')

    # store stock prices
    stock_prices = []

    # Iterate through each row in the News dataset
    for index, row in df.iterrows():
        publication_date = row['Date']
        # Check if the publication date exists in the stockPrice dataset
        if publication_date in stockPrices['Datetime'].values:
            # Retrieve the corresponding stock price
            stock_price = stockPrices.loc[stockPrices['Datetime'] == publication_date, 'Adj Close'].values[0]
            stock_prices.append(stock_price)
        else:
            stock_prices.append(None)  # If publication date not found, append None

    # Add the list of stock prices to the News dataset as a new column
    df[f'stock_price_after_{time}_mins'] = stock_prices
    return df

# %%
def turnToCSV(df,name):
    df.to_csv(fr'C:\Users\Legion\Desktop\FinalYearProject\data\{name}.csv')

# %%
News=pd.read_csv(r'C:\Users\Legion\Desktop\FinalYearProject\data\News.csv')

# %%
start_date = News['Date'].min().split()[0] 
end_date =  News['Date'].max().split()[0]  
stockPrices=getStockPrices(start_date,end_date)
turnToCSV(stockPrices,'stockPrices')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
News=removeSeconds(News)

# %%
News=addStockPrices(stockPrices,News)
News= News.dropna(subset=['stock_price'])
turnToCSV(News,'NewsWithStockPrice')

# %%
News
# Out:
#                     Date                                      article_title  \
# 13   2024-03-28 20:00:00  Mag 7 Stock Teases Breakout — While Nvidia Cli...
# 14   2024-03-28 19:33:00  Magnificent Seven Stocks To Buy And Watch: App...
# 15   2024-03-28 19:15:00  Apple's new iPad Pro likely to launch in May, ...
# 16   2024-03-28 17:47:00  Apple Plans New iPad Pro for May as Production...
# 17   2024-03-28 17:45:00        16 Most Profitable Tech Stocks To Invest In
# ..                   ...                                                ...
# 559  2024-03-05 17:10:00                             Goodbye, Project Titan
# 560  2024-03-05 16:59:00  Apple Stock Gloom Deepens as Pressure to Show ...
# 561  2024-03-05 16:55:00  What the shakeup in Magnificent 7 stocks means...
# 562  2024-03-05 16:46:00  Alphabet (GOOGL) Enhances Google Maps With New...
# 563  2024-03-05 16:43:00  Why Apple Stock Keeps Dropping, and What Could...
#
#                                                article    source_name  \
# 13   As Mag 7 stocks like Nvidia and Meta soar, Goo...  Yahoo Finance
# 14   Magnificent Seven stocks, including AI leader ...  Yahoo Finance
# 15   (Reuters) - Apple's overseas suppliers have in...  Yahoo Finance
# 16   (Bloomberg) -- Apple Inc.’s overseas suppliers...  Yahoo Finance
# 17   In this piece, we will take a look at the 16 m...  Yahoo Finance
# ..                                                 ...            ...
# 559  In this podcast, Motley Fool analyst Asit Shar...  Yahoo Finance
# 560  (Bloomberg) -- Apple Inc.’s move to shutter it...  Yahoo Finance
# 561  Stock market indices have been propped up on t...  Yahoo Finance
# 562  Alphabet’s GOOGL Google is gaining strong mome...  Yahoo Finance
# 563  Apple stock is in the red this year, so Wall S...  Yahoo Finance
#
#                                            source_link  stock_price
# 13   https://finance.yahoo.com/quote/AAPL/m/403395f...   171.479996
# 14   https://finance.yahoo.com/quote/AAPL/m/4205eaa...   172.149994
# 15   https://finance.yahoo.com/quote/AAPL/news/appl...   171.949997
# 16   https://finance.yahoo.com/quote/AAPL/news/appl...   171.264999
# 17   https://finance.yahoo.com/quote/AAPL/news/16-m...   171.229996
# ..                                                 ...          ...
# 559  https://finance.yahoo.com/quote/AAPL/news/good...   170.503799
# 560  https://finance.yahoo.com/quote/AAPL/news/appl...   170.259201
# 561  https://finance.yahoo.com/quote/AAPL/video/sha...   170.160004
# 562  https://finance.yahoo.com/quote/AAPL/news/alph...   169.865005
# 563  https://finance.yahoo.com/quote/AAPL/m/c76aec8...   169.970001
#
# [245 rows x 6 columns]

# %%
News=addStockPricesAfter(stockPrices,News,30)
News= News.dropna(subset=['stock_price_after_30_mins'])
turnToCSV(News,'NewsWithStockPrice')

# %%
News
# Out:
#                     Date                                      article_title  \
# 15   2024-03-28 19:45:00  Apple's new iPad Pro likely to launch in May, ...
# 16   2024-03-28 18:17:00  Apple Plans New iPad Pro for May as Production...
# 17   2024-03-28 18:15:00        16 Most Profitable Tech Stocks To Invest In
# 18   2024-03-28 15:52:00  Magnificent Seven Stocks To Buy And Watch: App...
# 19   2024-03-28 15:19:00  Apple-Supplier Foxconn Hits Record High, and O...
# ..                   ...                                                ...
# 559  2024-03-05 17:40:00                             Goodbye, Project Titan
# 560  2024-03-05 17:29:00  Apple Stock Gloom Deepens as Pressure to Show ...
# 561  2024-03-05 17:25:00  What the shakeup in Magnificent 7 stocks means...
# 562  2024-03-05 17:16:00  Alphabet (GOOGL) Enhances Google Maps With New...
# 563  2024-03-05 17:13:00  Why Apple Stock Keeps Dropping, and What Could...
#
#                                                article    source_name  \
# 15   (Reuters) - Apple's overseas suppliers have in...  Yahoo Finance
# 16   (Bloomberg) -- Apple Inc.’s overseas suppliers...  Yahoo Finance
# 17   In this piece, we will take a look at the 16 m...  Yahoo Finance
# 18   Magnificent Seven stocks, including AI leader ...  Yahoo Finance
# 19   Taiwan's Foxconn hit a record closing high on ...  Yahoo Finance
# ..                                                 ...            ...
# 559  In this podcast, Motley Fool analyst Asit Shar...  Yahoo Finance
# 560  (Bloomberg) -- Apple Inc.’s move to shutter it...  Yahoo Finance
# 561  Stock market indices have been propped up on t...  Yahoo Finance
# 562  Alphabet’s GOOGL Google is gaining strong mome...  Yahoo Finance
# 563  Apple stock is in the red this year, so Wall S...  Yahoo Finance
#
#                                            source_link  stock_price  \
# 15   https://finance.yahoo.com/quote/AAPL/news/appl...   171.949997
# 16   https://finance.yahoo.com/quote/AAPL/news/appl...   171.264999
# 17   https://finance.yahoo.com/quote/AAPL/news/16-m...   171.229996
# 18   https://finance.yahoo.com/quote/AAPL/m/4205eaa...   170.705002
# 19   https://finance.yahoo.com/quote/AAPL/m/d8d8576...   170.789993
# ..                                                 ...          ...
# 559  https://finance.yahoo.com/quote/AAPL/news/good...   170.503799
# 560  https://finance.yahoo.com/quote/AAPL/news/appl...   170.259201
# 561  https://finance.yahoo.com/quote/AAPL/video/sha...   170.160004
# 562  https://finance.yahoo.com/quote/AAPL/news/alph...   169.865005
# 563  https://finance.yahoo.com/quote/AAPL/m/c76aec8...   169.970001
#
#      stock_price_after_30_mins
# 15                  171.964996
# 16                  171.604996
# 17                  171.705002
# 18                  170.994995
# 19                  170.789993
# ..                         ...
# 559                 170.317596
# 560                 170.785004
# 561                 170.804993
# 562                 170.692505
# 563                 170.528793
#
# [236 rows x 7 columns]
