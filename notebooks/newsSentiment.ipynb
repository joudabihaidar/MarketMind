# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\Legion\Desktop\FinalYearProject\data\NewsWithStockPrice.csv')
df.head(3)
# Out:
#                   Date                                      article_title  \
# 0  2024-04-08 18:00:00         Could Apple Help You Retire a Millionaire?
# 1  2024-04-08 16:45:00  EU regulators assess Apple's plan for complyin...
# 2  2024-04-08 16:45:00  UPDATE 1-EU regulators assess Apple's plan for...
#
#                                              article    source_name  \
# 0  Apple (NASDAQ: AAPL) has made a lot of million...  Yahoo Finance
# 1  By Foo Yun CheeBRUSSELS (Reuters) -EU antitrus...  Yahoo Finance
# 2  (Adds Apple comment, details)By Foo Yun CheeBR...  Yahoo Finance
#
#                                          source_link  stock_price  \
# 0  https://finance.yahoo.com/quote/AAPL/news/coul...   168.625000
# 1  https://finance.yahoo.com/quote/AAPL/news/eu-r...   168.485001
# 2  https://finance.yahoo.com/quote/AAPL/news/1-eu...   168.485001
#
#    stock_price_after_30_mins  change_percentage  label
# 0                 168.720001           0.056339      1
# 1                 168.750000           0.157284      1
# 2                 168.750000           0.157284      1

# %%
sentiments = SentimentIntensityAnalyzer()


positive_scores = []
negative_scores = []
neutral_scores = []
compound_scores = []


for article in df["article"]:
    scores = sentiments.polarity_scores(article)
    positive_scores.append(scores["pos"])
    negative_scores.append(scores["neg"])
    neutral_scores.append(scores["neu"])
    compound_scores.append(scores["compound"])


df["Positive"] = positive_scores
df["Negative"] = negative_scores
df["Neutral"] = neutral_scores
df["Compound"] = compound_scores

# %%
df.head(3)
# Out:
#                   Date                                      article_title  \
# 0  2024-04-08 18:00:00         Could Apple Help You Retire a Millionaire?
# 1  2024-04-08 16:45:00  EU regulators assess Apple's plan for complyin...
# 2  2024-04-08 16:45:00  UPDATE 1-EU regulators assess Apple's plan for...
#
#                                              article    source_name  \
# 0  Apple (NASDAQ: AAPL) has made a lot of million...  Yahoo Finance
# 1  By Foo Yun CheeBRUSSELS (Reuters) -EU antitrus...  Yahoo Finance
# 2  (Adds Apple comment, details)By Foo Yun CheeBR...  Yahoo Finance
#
#                                          source_link  stock_price  \
# 0  https://finance.yahoo.com/quote/AAPL/news/coul...   168.625000
# 1  https://finance.yahoo.com/quote/AAPL/news/eu-r...   168.485001
# 2  https://finance.yahoo.com/quote/AAPL/news/1-eu...   168.485001
#
#    stock_price_after_30_mins  change_percentage  label  Positive  Negative  \
# 0                 168.720001           0.056339      1     0.117     0.034
# 1                 168.750000           0.157284      1     0.047     0.039
# 2                 168.750000           0.157284      1     0.046     0.038
#
#    Neutral  Compound
# 0    0.848    0.9968
# 1    0.914    0.3818
# 2    0.916    0.3818

# %%
score = df["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
df["Sentiment"] = sentiment

# %%
df.head(5)
# Out:
#                   Date                                      article_title  \
# 0  2024-04-08 18:00:00         Could Apple Help You Retire a Millionaire?
# 1  2024-04-08 16:45:00  EU regulators assess Apple's plan for complyin...
# 2  2024-04-08 16:45:00  UPDATE 1-EU regulators assess Apple's plan for...
# 3  2024-04-08 16:44:00  Magnificent Seven Stocks To Buy And Watch: Tes...
# 4  2024-04-08 16:32:00      Spotify Goes A Step Further On Its AI Journey
#
#                                              article    source_name  \
# 0  Apple (NASDAQ: AAPL) has made a lot of million...  Yahoo Finance
# 1  By Foo Yun CheeBRUSSELS (Reuters) -EU antitrus...  Yahoo Finance
# 2  (Adds Apple comment, details)By Foo Yun CheeBR...  Yahoo Finance
# 3  Magnificent Seven stocks, including AI leader ...  Yahoo Finance
# 4  Spotify Technology S.A. (NYSE: SPOT) continues...  Yahoo Finance
#
#                                          source_link  stock_price  \
# 0  https://finance.yahoo.com/quote/AAPL/news/coul...   168.625000
# 1  https://finance.yahoo.com/quote/AAPL/news/eu-r...   168.485001
# 2  https://finance.yahoo.com/quote/AAPL/news/1-eu...   168.485001
# 3  https://finance.yahoo.com/quote/AAPL/m/4205eaa...   168.464996
# 4  https://finance.yahoo.com/quote/AAPL/news/spot...   168.639999
#
#    stock_price_after_30_mins  change_percentage  label  Positive  Negative  \
# 0                 168.720001           0.056339      1     0.117     0.034
# 1                 168.750000           0.157284      1     0.047     0.039
# 2                 168.750000           0.157284      1     0.046     0.038
# 3                 168.759995           0.175109      1     0.310     0.000
# 4                 168.589996          -0.029651     -1     0.063     0.037
#
#    Neutral  Compound Sentiment
# 0    0.848    0.9968  Positive
# 1    0.914    0.3818  Positive
# 2    0.916    0.3818  Positive
# 3    0.690    0.8442  Positive
# 4    0.900    0.9535  Positive
