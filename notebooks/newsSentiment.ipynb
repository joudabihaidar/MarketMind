# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\Legion\Desktop\FinalYearProject\News.csv')
df.head(3)
# Out:
#                         Date  \
# 0  2024-03-29 08:41:00+00:00
# 1  2024-03-29 08:09:27+00:00
# 2  2024-03-29 04:22:06+00:00
#
#                                        article_title  \
# 0  Warren Buffett Is Raking In $4.36 Billion in A...
# 1  Huawei Profit Surges as It Takes Share From Ap...
# 2  20 Countries that Receive the Most Foreign Dir...
#
#                                              article    source_name  \
# 0  For nearly 60 years, Berkshire Hathaway (NYSE:...  Yahoo Finance
# 1  (Bloomberg) -- Huawei Technologies Co. sustain...  Yahoo Finance
# 2  In this article, we will look at 20 countries ...  Yahoo Finance
#
#                                          source_link Unnamed: 5 Unnamed: 6  \
# 0  https://finance.yahoo.com/quote/AAPL/news/warr...        NaN        NaN
# 1  https://finance.yahoo.com/quote/AAPL/news/huaw...        NaN        NaN
# 2  https://finance.yahoo.com/quote/AAPL/news/20-c...        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 205 Unnamed: 206  \
# 0        NaN        NaN        NaN  ...          NaN          NaN
# 1        NaN        NaN        NaN  ...          NaN          NaN
# 2        NaN        NaN        NaN  ...          NaN          NaN
#
#   Unnamed: 207 Unnamed: 208 Unnamed: 209 Unnamed: 210 Unnamed: 211  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 212 Unnamed: 213 Unnamed: 214
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
#
# [3 rows x 215 columns]

# %%
sentiments = SentimentIntensityAnalyzer()


positive_scores = []
negative_scores = []
neutral_scores = []
compound_scores = []


for article in df["article"]:
    scores = sentiments.polarity_scores(article)
    positive_scores.append(scores["pos"])
    negative_scores.append(scores["neg"])
    neutral_scores.append(scores["neu"])
    compound_scores.append(scores["compound"])


df["Positive"] = positive_scores
df["Negative"] = negative_scores
df["Neutral"] = neutral_scores
df["Compound"] = compound_scores

# %%
df.head(3)
# Out:
#                         Date  \
# 0  2024-03-29 08:41:00+00:00
# 1  2024-03-29 08:09:27+00:00
# 2  2024-03-29 04:22:06+00:00
#
#                                        article_title  \
# 0  Warren Buffett Is Raking In $4.36 Billion in A...
# 1  Huawei Profit Surges as It Takes Share From Ap...
# 2  20 Countries that Receive the Most Foreign Dir...
#
#                                              article    source_name  \
# 0  For nearly 60 years, Berkshire Hathaway (NYSE:...  Yahoo Finance
# 1  (Bloomberg) -- Huawei Technologies Co. sustain...  Yahoo Finance
# 2  In this article, we will look at 20 countries ...  Yahoo Finance
#
#                                          source_link Unnamed: 5 Unnamed: 6  \
# 0  https://finance.yahoo.com/quote/AAPL/news/warr...        NaN        NaN
# 1  https://finance.yahoo.com/quote/AAPL/news/huaw...        NaN        NaN
# 2  https://finance.yahoo.com/quote/AAPL/news/20-c...        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 209 Unnamed: 210  \
# 0        NaN        NaN        NaN  ...          NaN          NaN
# 1        NaN        NaN        NaN  ...          NaN          NaN
# 2        NaN        NaN        NaN  ...          NaN          NaN
#
#   Unnamed: 211 Unnamed: 212 Unnamed: 213 Unnamed: 214 Positive Negative  \
# 0          NaN          NaN          NaN          NaN    0.131    0.035
# 1          NaN          NaN          NaN          NaN    0.086    0.060
# 2          NaN          NaN          NaN          NaN    0.090    0.011
#
#   Neutral Compound
# 0   0.834   0.9993
# 1   0.854   0.9273
# 2   0.899   0.9995
#
# [3 rows x 219 columns]

# %%
score = df["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
df["Sentiment"] = sentiment

# %%
df.head(5)
# Out:
#                         Date  \
# 0  2024-03-29 08:41:00+00:00
# 1  2024-03-29 08:09:27+00:00
# 2  2024-03-29 04:22:06+00:00
# 3  2024-03-29 01:33:10+00:00
# 4  2024-03-28 21:11:33+00:00
#
#                                        article_title  \
# 0  Warren Buffett Is Raking In $4.36 Billion in A...
# 1  Huawei Profit Surges as It Takes Share From Ap...
# 2  20 Countries that Receive the Most Foreign Dir...
# 3  20 Countries with the Lowest Homeless Populati...
# 4  Q1 2024 Takeaways: The rise and fall of the Ma...
#
#                                              article    source_name  \
# 0  For nearly 60 years, Berkshire Hathaway (NYSE:...  Yahoo Finance
# 1  (Bloomberg) -- Huawei Technologies Co. sustain...  Yahoo Finance
# 2  In this article, we will look at 20 countries ...  Yahoo Finance
# 3  In this article, we will be navigating through...  Yahoo Finance
# 4  As the first quarter of 2024 draws to a close,...  Yahoo Finance
#
#                                          source_link Unnamed: 5 Unnamed: 6  \
# 0  https://finance.yahoo.com/quote/AAPL/news/warr...        NaN        NaN
# 1  https://finance.yahoo.com/quote/AAPL/news/huaw...        NaN        NaN
# 2  https://finance.yahoo.com/quote/AAPL/news/20-c...        NaN        NaN
# 3  https://finance.yahoo.com/quote/AAPL/news/20-c...        NaN        NaN
# 4  https://finance.yahoo.com/quote/AAPL/video/q1-...        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 210 Unnamed: 211  \
# 0        NaN        NaN        NaN  ...          NaN          NaN
# 1        NaN        NaN        NaN  ...          NaN          NaN
# 2        NaN        NaN        NaN  ...          NaN          NaN
# 3        NaN        NaN        NaN  ...          NaN          NaN
# 4        NaN        NaN        NaN  ...          NaN          NaN
#
#   Unnamed: 212 Unnamed: 213 Unnamed: 214 Positive Negative Neutral Compound  \
# 0          NaN          NaN          NaN    0.131    0.035   0.834   0.9993
# 1          NaN          NaN          NaN    0.086    0.060   0.854   0.9273
# 2          NaN          NaN          NaN    0.090    0.011   0.899   0.9995
# 3          NaN          NaN          NaN    0.053    0.090   0.857  -0.9964
# 4          NaN          NaN          NaN    0.158    0.027   0.815   0.9997
#
#   Sentiment
# 0  Positive
# 1  Positive
# 2  Positive
# 3  Negative
# 4  Positive
#
# [5 rows x 220 columns]
