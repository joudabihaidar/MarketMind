# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\Legion\Desktop\FinalYearProject\data\News.csv')
df.head(3)
# Out:
#                         Date  \
# 0  2024-04-01 16:55:42+00:00
# 1  2024-04-01 16:28:28+00:00
# 2  2024-04-01 16:00:21+00:00
#
#                                        article_title  \
# 0  Magnificent Seven Stocks To Buy And Watch: Goo...
# 1         How the 'Magnificent 7' became the 'Mag 4'
# 2  AI-powered stocks will face increasingly stiff...
#
#                                              article    source_name  \
# 0  Magnificent Seven stocks, including AI leader ...  Yahoo Finance
# 1  As the first quarter of 2024 draws to a close,...  Yahoo Finance
# 2  The tech sector has been on a run with chip po...  Yahoo Finance
#
#                                          source_link
# 0  https://finance.yahoo.com/quote/AAPL/m/4205eaa...
# 1  https://finance.yahoo.com/quote/AAPL/video/mag...
# 2  https://finance.yahoo.com/quote/AAPL/video/ai-...

# %%
sentiments = SentimentIntensityAnalyzer()


positive_scores = []
negative_scores = []
neutral_scores = []
compound_scores = []


for article in df["article"]:
    scores = sentiments.polarity_scores(article)
    positive_scores.append(scores["pos"])
    negative_scores.append(scores["neg"])
    neutral_scores.append(scores["neu"])
    compound_scores.append(scores["compound"])


df["Positive"] = positive_scores
df["Negative"] = negative_scores
df["Neutral"] = neutral_scores
df["Compound"] = compound_scores

# %%
df.head(3)
# Out:
#                         Date  \
# 0  2024-04-01 16:55:42+00:00
# 1  2024-04-01 16:28:28+00:00
# 2  2024-04-01 16:00:21+00:00
#
#                                        article_title  \
# 0  Magnificent Seven Stocks To Buy And Watch: Goo...
# 1         How the 'Magnificent 7' became the 'Mag 4'
# 2  AI-powered stocks will face increasingly stiff...
#
#                                              article    source_name  \
# 0  Magnificent Seven stocks, including AI leader ...  Yahoo Finance
# 1  As the first quarter of 2024 draws to a close,...  Yahoo Finance
# 2  The tech sector has been on a run with chip po...  Yahoo Finance
#
#                                          source_link  Positive  Negative  \
# 0  https://finance.yahoo.com/quote/AAPL/m/4205eaa...     0.310     0.000
# 1  https://finance.yahoo.com/quote/AAPL/video/mag...     0.109     0.000
# 2  https://finance.yahoo.com/quote/AAPL/video/ai-...     0.114     0.026
#
#    Neutral  Compound
# 0    0.690    0.8442
# 1    0.891    0.8979
# 2    0.860    0.9688

# %%
score = df["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
df["Sentiment"] = sentiment

# %%
df.head(5)
# Out:
#                         Date  \
# 0  2024-04-01 16:55:42+00:00
# 1  2024-04-01 16:28:28+00:00
# 2  2024-04-01 16:00:21+00:00
# 3  2024-04-01 14:50:31+00:00
# 4  2024-04-01 14:47:00+00:00
#
#                                        article_title  \
# 0  Magnificent Seven Stocks To Buy And Watch: Goo...
# 1         How the 'Magnificent 7' became the 'Mag 4'
# 2  AI-powered stocks will face increasingly stiff...
# 3  Apple Sales, Earnings Seen Declining In 2024 A...
# 4  Forecasts for Apple’s Quarterly Revenue Could ...
#
#                                              article    source_name  \
# 0  Magnificent Seven stocks, including AI leader ...  Yahoo Finance
# 1  As the first quarter of 2024 draws to a close,...  Yahoo Finance
# 2  The tech sector has been on a run with chip po...  Yahoo Finance
# 3  A Wall Street firm slashed its price target on...  Yahoo Finance
# 4  The stock dropped 11% in the first quarter, pr...  Yahoo Finance
#
#                                          source_link  Positive  Negative  \
# 0  https://finance.yahoo.com/quote/AAPL/m/4205eaa...     0.310     0.000
# 1  https://finance.yahoo.com/quote/AAPL/video/mag...     0.109     0.000
# 2  https://finance.yahoo.com/quote/AAPL/video/ai-...     0.114     0.026
# 3  https://finance.yahoo.com/quote/AAPL/m/a5fa64d...     0.000     0.256
# 4  https://finance.yahoo.com/quote/AAPL/m/49d5f41...     0.050     0.136
#
#    Neutral  Compound Sentiment
# 0    0.690    0.8442  Positive
# 1    0.891    0.8979  Positive
# 2    0.860    0.9688  Positive
# 3    0.744   -0.6369  Negative
# 4    0.814   -0.4215  Negative
