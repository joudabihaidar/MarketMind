# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\Legion\Desktop\FinalYearProject\data\NewsWithStockPrice.csv')
df.head(3)
# Out:
#                   Date                                      article_title  \
# 0  2024-04-11 17:47:00  Apple plans Mac line overhaul with AI-focused ...
# 1  2024-04-11 17:44:00  UPDATE 2-Apple plans Mac line overhaul with AI...
# 2  2024-04-11 17:25:00  Apple’s Services business is a bright spot in ...
#
#                                              article    source_name  \
# 0  (Reuters) -Apple is nearing the production of ...  Yahoo Finance
# 1  (Adds context and background in paragraphs 3-4...  Yahoo Finance
# 2  Apple’s (AAPL) 2024 has been rough so far. But...  Yahoo Finance
#
#                                          source_link  stock_price  \
# 0  https://finance.yahoo.com/quote/AAPL/news/appl...   171.460007
# 1  https://finance.yahoo.com/quote/AAPL/news/1-ap...   171.160004
# 2  https://finance.yahoo.com/quote/AAPL/news/appl...   170.240005
#
#    stock_price_after_30_mins  change_percentage  label
# 0                 172.764999           0.761106      1
# 1                 172.738007           0.921946      1
# 2                 171.964493           1.012974      1

# %%
sentiments = SentimentIntensityAnalyzer()


positive_scores = []
negative_scores = []
neutral_scores = []
compound_scores = []


for article in df["article"]:
    scores = sentiments.polarity_scores(article)
    positive_scores.append(scores["pos"])
    negative_scores.append(scores["neg"])
    neutral_scores.append(scores["neu"])
    compound_scores.append(scores["compound"])


df["Positive"] = positive_scores
df["Negative"] = negative_scores
df["Neutral"] = neutral_scores
df["Compound"] = compound_scores

# %%
df.head(3)
# Out:
#                   Date                                      article_title  \
# 0  2024-04-11 17:47:00  Apple plans Mac line overhaul with AI-focused ...
# 1  2024-04-11 17:44:00  UPDATE 2-Apple plans Mac line overhaul with AI...
# 2  2024-04-11 17:25:00  Apple’s Services business is a bright spot in ...
#
#                                              article    source_name  \
# 0  (Reuters) -Apple is nearing the production of ...  Yahoo Finance
# 1  (Adds context and background in paragraphs 3-4...  Yahoo Finance
# 2  Apple’s (AAPL) 2024 has been rough so far. But...  Yahoo Finance
#
#                                          source_link  stock_price  \
# 0  https://finance.yahoo.com/quote/AAPL/news/appl...   171.460007
# 1  https://finance.yahoo.com/quote/AAPL/news/1-ap...   171.160004
# 2  https://finance.yahoo.com/quote/AAPL/news/appl...   170.240005
#
#    stock_price_after_30_mins  change_percentage  label  Positive  Negative  \
# 0                 172.764999           0.761106      1     0.056     0.000
# 1                 172.738007           0.921946      1     0.055     0.000
# 2                 171.964493           1.012974      1     0.091     0.041
#
#    Neutral  Compound
# 0    0.944    0.9371
# 1    0.945    0.9371
# 2    0.868    0.9832

# %%
score = df["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
df["Sentiment"] = sentiment

# %%
df.head(5)
# Out:
#                   Date                                      article_title  \
# 0  2024-04-11 17:47:00  Apple plans Mac line overhaul with AI-focused ...
# 1  2024-04-11 17:44:00  UPDATE 2-Apple plans Mac line overhaul with AI...
# 2  2024-04-11 17:25:00  Apple’s Services business is a bright spot in ...
# 3  2024-04-11 16:51:00  Is Meta Stock A Buy After Debuting Latest AI C...
# 4  2024-04-11 14:16:00  Apple's AI iPhone Could See 5G-Like Upgrade Cycle
#
#                                              article    source_name  \
# 0  (Reuters) -Apple is nearing the production of ...  Yahoo Finance
# 1  (Adds context and background in paragraphs 3-4...  Yahoo Finance
# 2  Apple’s (AAPL) 2024 has been rough so far. But...  Yahoo Finance
# 3  Meta has surged by triple digits in 2023 but t...  Yahoo Finance
# 4  Apple stock could be due for a rerating when t...  Yahoo Finance
#
#                                          source_link  stock_price  \
# 0  https://finance.yahoo.com/quote/AAPL/news/appl...   171.460007
# 1  https://finance.yahoo.com/quote/AAPL/news/1-ap...   171.160004
# 2  https://finance.yahoo.com/quote/AAPL/news/appl...   170.240005
# 3  https://finance.yahoo.com/quote/AAPL/m/e5b1f22...   170.199997
# 4  https://finance.yahoo.com/quote/AAPL/m/8a11063...   168.880005
#
#    stock_price_after_30_mins  change_percentage  label  Positive  Negative  \
# 0                 172.764999           0.761106      1     0.056     0.000
# 1                 172.738007           0.921946      1     0.055     0.000
# 2                 171.964493           1.012974      1     0.091     0.041
# 3                 170.170197          -0.017509     -1     0.000     0.000
# 4                 168.520004          -0.213169     -1     0.000     0.000
#
#    Neutral  Compound Sentiment
# 0    0.944    0.9371  Positive
# 1    0.945    0.9371  Positive
# 2    0.868    0.9832  Positive
# 3    1.000    0.0000   Neutral
# 4    1.000    0.0000   Neutral
