# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta
import pytz
import concurrent.futures
# Out:
# Exception in thread Thread-1378:
# Traceback (most recent call last):
#   File "c:\Users\Legion\Desktop\FinalYearProject\finalProjectEnv\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "c:\Users\Legion\Desktop\FinalYearProject\finalProjectEnv\lib\site-packages\urllib3\connectionpool.py", line 382, in _make_request
#     self._validate_conn(conn)
#   File "c:\Users\Legion\Desktop\FinalYearProject\finalProjectEnv\lib\site-packages\urllib3\connectionpool.py", line 1010, in _validate_conn
#     conn.connect()
#   File "c:\Users\Legion\Desktop\FinalYearProject\finalProjectEnv\lib\site-packages\urllib3\connection.py", line 426, in connect
#     tls_in_tls=tls_in_tls,
#   File "c:\Users\Legion\Desktop\FinalYearProject\finalProjectEnv\lib\site-packages\urllib3\util\ssl_.py", line 450, in ssl_wrap_socket
#     sock, context, tls_in_tls, server_hostname=server_hostname
# ...

# %%
aapl = yf.download(tickers="AAPL", period="7d", interval="1m")
#aapl.reset_index(inplace=True)
aapl.head(3)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2024-03-20 09:30:00-04:00  175.729996  176.100006  175.500000  175.729996
# 2024-03-20 09:31:00-04:00  175.710007  176.029999  175.669998  175.709900
# 2024-03-20 09:32:00-04:00  175.679993  175.819901  175.610001  175.729996
#
#                             Adj Close   Volume
# Datetime
# 2024-03-20 09:30:00-04:00  175.729996  1350666
# 2024-03-20 09:31:00-04:00  175.709900   140912
# 2024-03-20 09:32:00-04:00  175.729996   176795

# %%
data=pd.read_csv(r'C:\Users\Legion\Desktop\FinalYearProject\data\News.csv')
data.head(3)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 565 entries, 0 to 564
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           565 non-null    object
#  1   article_title  565 non-null    object
#  2   article        565 non-null    object
#  3   source_name    565 non-null    object
#  4   source_link    565 non-null    object
# dtypes: object(5)
# memory usage: 22.2+ KB

# %%
# def removeSeconds(date):
#     # Parse the datetime string into a datetime object
#     dt_obj = datetime.strptime(date, '%Y-%m-%d %H:%M:%S%z')

#     # Replace the seconds with '00'
#     dt_obj = dt_obj.replace(second=0)

#     # Convert the datetime object back to a string
#     modified_datetime_string = dt_obj.strftime('%Y-%m-%d %H:%M:%S%z')

#     return modified_datetime_string

# for date in data['Date']:
#     modified_date_utc = removeSeconds(date)
#     print(modified_date_utc)
modified_dates=[]
for date in data['Date']:
    format = '%Y-%m-%d %H:%M:%S%z'
    date = datetime.strptime(date, format)
    modified_date = date.replace(second=0)
    print(modified_date)
    modified_dates.append(modified_date)
    #print(data['Date'])
    #data.index = data.index.set_value(data.index.get_loc(date), modified_date)
    #data.index.values[data.index.get_loc(date)] = modified_date
data['Date']=modified_dates
# Out:
# 2024-03-30 08:45:00+00:00
# 2024-03-29 22:29:00+00:00
# 2024-03-29 16:03:00+00:00
# 2024-03-29 13:00:00+00:00
# 2024-03-29 11:39:00+00:00
# 2024-03-29 11:15:00+00:00
# 2024-03-29 10:45:00+00:00
# 2024-03-29 10:00:00+00:00
# 2024-03-29 08:41:00+00:00
# 2024-03-29 08:09:00+00:00
# 2024-03-29 04:22:00+00:00
# 2024-03-29 01:33:00+00:00
# 2024-03-28 21:11:00+00:00
# 2024-03-28 20:00:00+00:00
# 2024-03-28 19:33:00+00:00
# 2024-03-28 19:15:00+00:00
# 2024-03-28 17:47:00+00:00
# 2024-03-28 17:45:00+00:00
# 2024-03-28 15:22:00+00:00
# 2024-03-28 14:49:00+00:00
# 2024-03-28 14:49:00+00:00
# 2024-03-28 14:46:00+00:00
# 2024-03-28 14:00:00+00:00
# 2024-03-28 13:57:00+00:00
# 2024-03-28 13:38:00+00:00
# 2024-03-28 13:27:00+00:00
# 2024-03-28 13:21:00+00:00
# 2024-03-28 13:00:00+00:00
# 2024-03-28 11:57:00+00:00
# 2024-03-28 11:40:00+00:00
# 2024-03-28 11:13:00+00:00
# 2024-03-28 10:45:00+00:00
# 2024-03-28 10:30:00+00:00
# 2024-03-28 10:07:00+00:00
# 2024-03-28 10:00:00+00:00
# ...

# %%
data
# Out:
#                          Date  \
# 0   2024-03-30 08:45:00+00:00
# 1   2024-03-29 22:29:00+00:00
# 2   2024-03-29 16:03:00+00:00
# 3   2024-03-29 13:00:00+00:00
# 4   2024-03-29 11:39:00+00:00
# ..                        ...
# 560 2024-03-05 16:59:00+00:00
# 561 2024-03-05 16:55:00+00:00
# 562 2024-03-05 16:46:00+00:00
# 563 2024-03-05 16:43:00+00:00
# 564 2024-03-05 16:27:00+00:00
#
#                                          article_title  \
# 0    Will Warren Buffett Sell More Apple Stock Beca...
# 1       16 Easiest Countries to get a Residence Permit
# 2                       13 Best Growth ETFs To Buy Now
# 3       Is Trending Stock Apple Inc. (AAPL) a Buy Now?
# 4                14 Best Stocks To Buy According to AI
# ..                                                 ...
# 560  Apple Stock Gloom Deepens as Pressure to Show ...
# 561  What the shakeup in Magnificent 7 stocks means...
# 562  Alphabet (GOOGL) Enhances Google Maps With New...
# ...

# %%
#data=pd.read_csv(r'C:\Users\Legion\Desktop\FinalYearProject\data\News.csv')
#data.head(3)
data['Date'] = pd.to_datetime(data['Date'])
data
# Out:
#                          Date  \
# 0   2024-03-30 08:45:00+00:00
# 1   2024-03-29 22:29:00+00:00
# 2   2024-03-29 16:03:00+00:00
# 3   2024-03-29 13:00:00+00:00
# 4   2024-03-29 11:39:00+00:00
# ..                        ...
# 560 2024-03-05 16:59:00+00:00
# 561 2024-03-05 16:55:00+00:00
# 562 2024-03-05 16:46:00+00:00
# 563 2024-03-05 16:43:00+00:00
# 564 2024-03-05 16:27:00+00:00
#
#                                          article_title  \
# 0    Will Warren Buffett Sell More Apple Stock Beca...
# 1       16 Easiest Countries to get a Residence Permit
# 2                       13 Best Growth ETFs To Buy Now
# 3       Is Trending Stock Apple Inc. (AAPL) a Buy Now?
# 4                14 Best Stocks To Buy According to AI
# ..                                                 ...
# 560  Apple Stock Gloom Deepens as Pressure to Show ...
# 561  What the shakeup in Magnificent 7 stocks means...
# 562  Alphabet (GOOGL) Enhances Google Maps With New...
# ...

# %%
def convertTimezone(timezone, df,name):
    """
    Converting timestamps in to a specified timezone.

    Arguments:
        timezone (str): Target timezone to convert timestamps to.
        df : DataFrame containing a column of timestamp strings.
        name: name of the timestamp column

    Returns a dataFrame with timestamps converted to the specified timezone.
    """

    target_tz = pytz.timezone(timezone)

    if df.index is not None:
        # Convert the index to a timezone-aware index
        df.index = pd.to_datetime(df.index, utc=True).tz_convert(timezone)

    else:
        # Convert timestamp column to datetime objects
        df[name] = pd.to_datetime(df[name])
        df[name] = df[name].dt.tz_convert(target_tz)
    return df

# %%
hist_df = convertTimezone('UTC', aapl,'Datetime')
hist_df
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-03-20 13:30:00+00:00  175.729996  176.100006  175.500000  175.729996
# 2024-03-20 13:31:00+00:00  175.710007  176.029999  175.669998  175.709900
# 2024-03-20 13:32:00+00:00  175.679993  175.819901  175.610001  175.729996
# 2024-03-20 13:33:00+00:00  175.725006  175.800003  175.630005  175.669998
# 2024-03-20 13:34:00+00:00  175.660004  175.660004  175.264008  175.307999
# ...                               ...         ...         ...         ...
# 2024-03-28 19:56:00+00:00  171.774994  171.860001  171.699997  171.835007
# 2024-03-28 19:57:00+00:00  171.845001  171.990005  171.800003  171.945007
# 2024-03-28 19:58:00+00:00  171.940002  171.949997  171.860001  171.860001
# 2024-03-28 19:59:00+00:00  171.860001  171.899994  171.259995  171.520004
# 2024-03-28 20:00:00+00:00  171.479996  171.479996  171.479996  171.479996
#
#                             Adj Close   Volume
# Datetime
# ...

# %%
# get specific stock price at a certain day and time
# it will take as parameters the date of the published article, the number of minutes after the article was published

# i need to make sure that the stock prices dataset has no index.
# and i need to convert its timezone to UTC
# i need to make sure that the end date is 1 day ahead.

# %%
# label the data

# %%
def getStockPrice(date):
    # date_string = '2024-03-05 14:30:00+00:00'
    # format = '%Y-%m-%d %H:%M:%S%z'
    # date = datetime.strptime(date_string, format) # to pass as an argument
    c=0
    end_date=date+timedelta(days=1)
    end_date=end_date.strftime("%Y-%m-%d %H:%M:%S%z").split()
    end_date=end_date[0]

    date= date.strftime("%Y-%m-%d %H:%M:%S%z").split()
    day=date[0]
    time=date[1].split("+")[0]

    data = yf.download(tickers='AAPL', start=day, end=end_date, interval='1m', index_col=0)
    data=convertTimezone('UTC',data,'Datetime')
    
    #if data.empty:
        #print(f"No data available for AAPL on {day}")

    data_at_time = data.between_time(time, time)

    if not data_at_time.empty:
        stock_price = data_at_time['Close'].values[0]
        c+=1
        #print(f"The stock price of AAPL on {day} at {time} was ${stock_price:.2f}")

    #else:
       # print(f"No data available for AAPL on {day} at {time}")
    return c

# %%
# testing if the function works:
#ticker = 'AAPL'
date = datetime(2024, 3, 5, 14, 30, 0)  # Assuming date is in UTC timezone with offset
getStockPrice(date)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 1

# %%
#ticker = 'AAPL'
date = datetime(2024, 3, 5, 14, 35, 0)  # Assuming date is in UTC timezone with offset
getStockPrice(date)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 1

# %%
date = datetime(2024, 3, 5, 16, 0, 0)  # Assuming date is in UTC timezone with offset
getStockPrice(date)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 1

# %%
for date in data['Date']:
    c=getStockPrice(date)
print(f"we got {c} stock prices back out of 565")
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: No data found for this date range, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: No data found for this date range, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: No data found for this date range, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: No data found for this date range, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: No data found for this date range, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: No data found for this date range, symbol may be delisted
# ...

# %%
data.index[0]
# Out:
# 0

# %%
data.shape
# Out:
# (565, 5)

# %%
import concurrent.futures

def getStockPrice(date):
    c = 0
    end_date = date + timedelta(days=1)
    end_date = end_date.strftime("%Y-%m-%d %H:%M:%S%z").split()[0]
    date_str = date.strftime("%Y-%m-%d %H:%M:%S%z").split()
    day = date_str[0]
    time = date_str[1].split("+")[0]

    data = yf.download(tickers='AAPL', start=day, end=end_date, interval='1m', index_col=0)
    data = convertTimezone('UTC', data, 'Datetime')

    data_at_time = data.between_time(time, time)

    if not data_at_time.empty:
        c += 1

    return c

# Function to process the dates using ThreadPoolExecutor
def process_dates(dates):
    with concurrent.futures.ThreadPoolExecutor() as executor:
        results = executor.map(getStockPrice, dates)
    return sum(results)

# Assuming 'data' is your DataFrame containing dates
c = process_dates(data['Date'])

print(f"We got {c} stock prices back out of {len(data)}")
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: No data found for this date range, symbol may be delisted
#
#
# 1 Failed download:
# - AAPL: No data found for this date range, symbol may be delisted
#
#
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
# 1 Failed download:
# - AAPL: No data found for this date range, symbol may be delisted
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
# ...
