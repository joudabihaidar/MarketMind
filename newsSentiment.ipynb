# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
import pandas as pd

# %%
df=pd.read_csv('News.csv')
df.head(3)
# Out:
#                         Date  \
# 0  2024-03-21 20:55:39+00:00
# 1  2024-03-21 20:43:56+00:00
# 2  2024-03-21 20:02:12+00:00
#
#                                        article_title  \
# 0  Why China's options in response to a TikTok ba...
# 1  US STOCKS-Wall Street hits record closing high...
# 2   Stocks Rally to New Highs Despite Apple's Losses
#
#                                              article    source_name  \
# 0  Chinese officials decried the lack of “fairnes...  Yahoo Finance
# 1  *Micron Technology surges after upbeat Q3 rev ...  Yahoo Finance
# 2  The S&P 500 was up 0.3%. The Nasdaq Composite ...  Yahoo Finance
#
#                                          source_link
# 0  https://finance.yahoo.com/quote/AAPL/news/why-...
# 1  https://finance.yahoo.com/quote/AAPL/news/us-s...
# 2  https://finance.yahoo.com/quote/AAPL/m/fa04871...

# %%
sentiments=SentimentIntensityAnalyzer()
df["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in df["article"]]
df["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in df["article"]]
df["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in df["article"]]
df['Compound'] = [sentiments.polarity_scores(i)["compound"] for i in df["article"]]

# %%
df.head(3)
# Out:
#                         Date  \
# 0  2024-03-21 20:55:39+00:00
# 1  2024-03-21 20:43:56+00:00
# 2  2024-03-21 20:02:12+00:00
#
#                                        article_title  \
# 0  Why China's options in response to a TikTok ba...
# 1  US STOCKS-Wall Street hits record closing high...
# 2   Stocks Rally to New Highs Despite Apple's Losses
#
#                                              article    source_name  \
# 0  Chinese officials decried the lack of “fairnes...  Yahoo Finance
# 1  *Micron Technology surges after upbeat Q3 rev ...  Yahoo Finance
# 2  The S&P 500 was up 0.3%. The Nasdaq Composite ...  Yahoo Finance
#
#                                          source_link  Positive  Negative  \
# 0  https://finance.yahoo.com/quote/AAPL/news/why-...     0.067     0.072
# 1  https://finance.yahoo.com/quote/AAPL/news/us-s...     0.077     0.057
# 2  https://finance.yahoo.com/quote/AAPL/m/fa04871...     0.141     0.000
#
#    Neutral  Compound
# 0    0.861   -0.8814
# 1    0.866    0.8946
# 2    0.859    0.6808

# %%
score = df["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
df["Sentiment"] = sentiment

# %%
df.head(3)
# Out:
#                         Date  \
# 0  2024-03-21 20:55:39+00:00
# 1  2024-03-21 20:43:56+00:00
# 2  2024-03-21 20:02:12+00:00
#
#                                        article_title  \
# 0  Why China's options in response to a TikTok ba...
# 1  US STOCKS-Wall Street hits record closing high...
# 2   Stocks Rally to New Highs Despite Apple's Losses
#
#                                              article    source_name  \
# 0  Chinese officials decried the lack of “fairnes...  Yahoo Finance
# 1  *Micron Technology surges after upbeat Q3 rev ...  Yahoo Finance
# 2  The S&P 500 was up 0.3%. The Nasdaq Composite ...  Yahoo Finance
#
#                                          source_link  Positive  Negative  \
# 0  https://finance.yahoo.com/quote/AAPL/news/why-...     0.067     0.072
# 1  https://finance.yahoo.com/quote/AAPL/news/us-s...     0.077     0.057
# 2  https://finance.yahoo.com/quote/AAPL/m/fa04871...     0.141     0.000
#
#    Neutral  Compound Sentiment
# 0    0.861   -0.8814  Negative
# 1    0.866    0.8946  Positive
# 2    0.859    0.6808  Positive
