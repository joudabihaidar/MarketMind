# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
import pandas as pd

# %%
df=pd.read_csv('News.csv')
df.head(3)
# Out:
#                         Date  \
# 0  2024-03-23 09:30:00+00:00
# 1  2024-03-23 08:00:00+00:00
# 2  2024-03-23 03:25:21+00:00
#
#                                        article_title  \
# 0  Ghost of Microsoft Stalks Apple as DOJ Takes I...
# 1  43.5% of Warren Buffett's $372 Billion Portfol...
# 2         China commerce minister meets Apple's Cook
#
#                                              article    source_name  \
# 0  The ghost of old Microsoft hung in the air thi...  Yahoo Finance
# 1  Warren Buffett is considered one of the best i...  Yahoo Finance
# 2  SHANGHAI, March 23 (Reuters) - China's commerc...  Yahoo Finance
#
#                                          source_link
# 0  https://finance.yahoo.com/quote/AAPL/m/e5ab854...
# 1  https://finance.yahoo.com/quote/AAPL/news/43-5...
# 2  https://finance.yahoo.com/quote/AAPL/news/chin...

# %%
sentiments=SentimentIntensityAnalyzer()
df["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in df["article"]]
df["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in df["article"]]
df["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in df["article"]]
df['Compound'] = [sentiments.polarity_scores(i)["compound"] for i in df["article"]]

# %%
df.head(3)
# Out:
#                         Date  \
# 0  2024-03-23 09:30:00+00:00
# 1  2024-03-23 08:00:00+00:00
# 2  2024-03-23 03:25:21+00:00
#
#                                        article_title  \
# 0  Ghost of Microsoft Stalks Apple as DOJ Takes I...
# 1  43.5% of Warren Buffett's $372 Billion Portfol...
# 2         China commerce minister meets Apple's Cook
#
#                                              article    source_name  \
# 0  The ghost of old Microsoft hung in the air thi...  Yahoo Finance
# 1  Warren Buffett is considered one of the best i...  Yahoo Finance
# 2  SHANGHAI, March 23 (Reuters) - China's commerc...  Yahoo Finance
#
#                                          source_link  Positive  Negative  \
# 0  https://finance.yahoo.com/quote/AAPL/m/e5ab854...     0.084     0.123
# 1  https://finance.yahoo.com/quote/AAPL/news/43-5...     0.159     0.034
# 2  https://finance.yahoo.com/quote/AAPL/news/chin...     0.073     0.028
#
#    Neutral  Compound
# 0    0.793   -0.4767
# ...

# %%
score = df["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
df["Sentiment"] = sentiment

# %%
df.head(3)
# Out:
#                         Date  \
# 0  2024-03-23 09:30:00+00:00
# 1  2024-03-23 08:00:00+00:00
# 2  2024-03-23 03:25:21+00:00
#
#                                        article_title  \
# 0  Ghost of Microsoft Stalks Apple as DOJ Takes I...
# 1  43.5% of Warren Buffett's $372 Billion Portfol...
# 2         China commerce minister meets Apple's Cook
#
#                                              article    source_name  \
# 0  The ghost of old Microsoft hung in the air thi...  Yahoo Finance
# 1  Warren Buffett is considered one of the best i...  Yahoo Finance
# 2  SHANGHAI, March 23 (Reuters) - China's commerc...  Yahoo Finance
#
#                                          source_link  Positive  Negative  \
# 0  https://finance.yahoo.com/quote/AAPL/m/e5ab854...     0.084     0.123
# 1  https://finance.yahoo.com/quote/AAPL/news/43-5...     0.159     0.034
# 2  https://finance.yahoo.com/quote/AAPL/news/chin...     0.073     0.028
#
#    Neutral  Compound Sentiment
# ...

# %%
df.to_csv("News.csv", index=False)
